# %%
# !pip3 install openai
# Out:
# Requirement already satisfied: openai in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (0.28.1)
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: requests>=2.20 in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from openai) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from openai) (4.66.1)
# Requirement already satisfied: aiohttp in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from openai) (3.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.20->openai) (2023.11.17)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: colorama in c:\users\nabin\appdata\local\programs\python\python312\lib\site-packages (from tqdm->openai) (0.4.6)

# %%
import os
import openai
openai.api_key = "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"
openai.File.create(
  file=open("output_with_plotly_and_image_features.jsonl", "rb"),
  purpose='fine-tune'
)
# Out:
# <File file id=file-yK7P2L7b98EdpgOoz4pLSOPy at 0x1a156c9ad50> JSON: {
#   "object": "file",
#   "id": "file-yK7P2L7b98EdpgOoz4pLSOPy",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 167880,
#   "created_at": 1707582707,
#   "status": "processed",
#   "status_details": null
# }

# %%
openai.FineTuningJob.create(training_file="file-yK7P2L7b98EdpgOoz4pLSOPy", model="gpt-3.5-turbo-1106",
  #    hyperparameters={
  #  "n_epochs":2
  #}
                            )
# Out:
# <FineTuningJob fine_tuning.job id=ftjob-uqxatKWBwQ2DD5UEo1LscK7A at 0x1a156d5b1b0> JSON: {
#   "object": "fine_tuning.job",
#   "id": "ftjob-uqxatKWBwQ2DD5UEo1LscK7A",
#   "model": "gpt-3.5-turbo-1106",
#   "created_at": 1707510107,
#   "finished_at": null,
#   "fine_tuned_model": null,
#   "organization_id": "org-QzNdgHXihCg09dJeDFtqXcWA",
#   "result_files": [],
#   "status": "validating_files",
#   "validation_file": null,
#   "training_file": "file-d1JH2S5xxUnwJpB95osASkcf",
#   "hyperparameters": {
#     "n_epochs": 2,
#     "batch_size": "auto",
#     "learning_rate_multiplier": "auto"
#   },
#   "trained_tokens": null,
#   "error": {
#     "error": null
#   }
# }

# %%
openai.FineTuningJob.list(limit=10)
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 openai.FineTuningJob.list(limit=10)
#
# File c:\Users\nabin\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\api_resources\abstract\paginatable_api_resource.py:82, in PaginatableAPIResource.list(cls, limit, starting_after, api_key, request_id, api_version, organization, api_base, api_type, **params)
#      68 requestor, url = cls.__prepare_list_requestor(
#      69     api_key,
#      70     api_version,
#    (...)
#      73     api_type,
#      74 )
#      76 params = {
#      77     **params,
#      78     "limit": limit,
#      79     "starting_after": starting_after,
#      80 }
# ---> 82 response, _, api_key = requestor.request(
#      83     "get", url, params, request_id=request_id
#      84 )
#      85 openai_object = util.convert_to_openai_object(
#      86     response, api_key, api_version, organization
#      87 )
#      88 openai_object._retrieve_params = params
#
# File c:\Users\nabin\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\api_requestor.py:299, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     278 def request(
#     279     self,
#     280     method,
#    (...)
#     287     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     288 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     289     result = self.request_raw(
#     290         method.lower(),
#     291         url,
#    (...)
#     297         request_timeout=request_timeout,
#     298     )
# --> 299     resp, got_stream = self._interpret_response(result, stream)
#     300     return resp, got_stream, self.api_key
#
# File c:\Users\nabin\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\api_requestor.py:710, in APIRequestor._interpret_response(self, result, stream)
#     702     return (
#     703         self._interpret_response_line(
#     704             line, result.status_code, result.headers, stream=True
#     705         )
#     706         for line in parse_stream(result.iter_lines())
#     707     ), True
#     708 else:
#     709     return (
# --> 710         self._interpret_response_line(
#     711             result.content.decode("utf-8"),
#     712             result.status_code,
#     713             result.headers,
#     714             stream=False,
#     715         ),
#     716         False,
#     717     )
#
# File c:\Users\nabin\AppData\Local\Programs\Python\Python312\Lib\site-packages\openai\api_requestor.py:775, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     773 stream_error = stream and "error" in resp.data
#     774 if stream_error or not 200 <= rcode < 300:
# --> 775     raise self.handle_error_response(
#     776         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     777     )
#     778 return resp
#
# APIError: The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_380f700289d6d9b40c142d3f60f41fef in your email.) {
#   "error": {
#     "message": "The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_380f700289d6d9b40c142d3f60f41fef in your email.)",
#     "type": "server_error",
#     "param": null,
#     "code": null
#   }
# } 500 {'error': {'message': 'The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_380f700289d6d9b40c142d3f60f41fef in your email.)', 'type': 'server_error', 'param': None, 'code': None}} {'Date': 'Fri, 09 Feb 2024 19:36:31 GMT', 'Content-Type': 'application/json', 'Content-Length': '369', 'Connection': 'keep-alive', 'x-request-id': 'req_380f700289d6d9b40c142d3f60f41fef', 'openai-processing-ms': '33', 'strict-transport-security': 'max-age=15724800; includeSubDomains', 'CF-Cache-Status': 'DYNAMIC', 'Server': 'cloudflare', 'CF-RAY': '852e8fcc885d2c64-ORD', 'alt-svc': 'h3=":443"; ma=86400'}
