# %%
# !pip3 install openai
# Out:
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import os
import openai
openai.api_key = "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"
openai.File.create(
  file=open("output_with_plotly_and_image_features.jsonl", "rb"),
  purpose='fine-tune'
)
# Out:
# <File file id=file-ECNErPOivfpRzsJJDrg2CVSw at 0x26ecd15b3e0> JSON: {
#   "object": "file",
#   "id": "file-ECNErPOivfpRzsJJDrg2CVSw",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 155183,
#   "created_at": 1707583122,
#   "status": "processed",
#   "status_details": null
# }

# %%
openai.FineTuningJob.create(training_file="file-ECNErPOivfpRzsJJDrg2CVSw", model="gpt-3.5-turbo-1106",
  #    hyperparameters={
  #  "n_epochs":2
  #}
                            )
# Out:
# <FineTuningJob fine_tuning.job id=ftjob-OkvIFCCWiEcJuwGAr3qxJtUW at 0x26ecd159310> JSON: {
#   "object": "fine_tuning.job",
#   "id": "ftjob-OkvIFCCWiEcJuwGAr3qxJtUW",
#   "model": "gpt-3.5-turbo-1106",
#   "created_at": 1707583131,
#   "finished_at": null,
#   "fine_tuned_model": null,
#   "organization_id": "org-QzNdgHXihCg09dJeDFtqXcWA",
#   "result_files": [],
#   "status": "validating_files",
#   "validation_file": null,
#   "training_file": "file-ECNErPOivfpRzsJJDrg2CVSw",
#   "hyperparameters": {
#     "n_epochs": "auto",
#     "batch_size": "auto",
#     "learning_rate_multiplier": "auto"
#   },
#   "trained_tokens": null,
#   "error": {
#     "error": null
#   }
# }

# %%
openai.FineTuningJob.list(limit=10)

# %%
# !pip install --upgrade nbformat
# Out:
# ...
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 23
#      18     fig.show()
#      20 sampleData = json.loads('[{    "species": "Species A",    "depth_zone": "Zone 1",    "count": 20},{    "species": "Species B",    "depth_zone": "Zone 1",    "count": 15},{    "species": "Species C",    "depth_zone": "Zone 2",    "count": 10},{    "species": "Species D",    "depth_zone": "Zone 2",    "count": 8},{    "species": "Species E",    "depth_zone": "Zone 3",    "count": 12},{    "species": "Species F",    "depth_zone": "Zone 3",    "count": 18}]')
# ---> 23 drawVisualization(sampleData)
#
# Cell In[6], line 18, in drawVisualization(data)
#       5 fig = go.Figure(data=[
#       6     go.Bar(name='Zone 1', x=[d['species'] for d in data if d['depth_zone'] == 'Zone 1'], y=[d['count'] for d in data if d['depth_zone'] == 'Zone 1'], marker=dict(color='mediumblue')),
# ...
