# %%
# !pip3 install openai

# %%
import os
import openai
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.File.create(
  file=open("with-observation.jsonl", "rb"),
  purpose='fine-tune'
)
# Out:
# <File file id=file-sQoUKIivVgjlR85xUFO9pv6V at 0x1090eec90> JSON: {
#   "object": "file",
#   "id": "file-sQoUKIivVgjlR85xUFO9pv6V",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 476664,
#   "created_at": 1695838674,
#   "status": "uploaded",
#   "status_details": null
# }

# %%
openai.FineTuningJob.create(training_file="file-sQoUKIivVgjlR85xUFO9pv6V", model="gpt-3.5-turbo")
# Out:
# <FineTuningJob fine_tuning.job id=ftjob-TRB5DR77lQAbq7tmkEZqjfNN at 0x103fb3f50> JSON: {
#   "object": "fine_tuning.job",
#   "id": "ftjob-TRB5DR77lQAbq7tmkEZqjfNN",
#   "model": "gpt-3.5-turbo-0613",
#   "created_at": 1695838682,
#   "finished_at": null,
#   "fine_tuned_model": null,
#   "organization_id": "org-QzNdgHXihCg09dJeDFtqXcWA",
#   "result_files": [],
#   "status": "validating_files",
#   "validation_file": null,
#   "training_file": "file-sQoUKIivVgjlR85xUFO9pv6V",
#   "hyperparameters": {
#     "n_epochs": "auto"
#   },
#   "trained_tokens": null,
#   "error": null
# }

# %%
openai.FineTuningJob.list(limit=10)
# Out:
# <OpenAIObject list at 0x109494530> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "fine_tuning.job",
#       "id": "ftjob-TRB5DR77lQAbq7tmkEZqjfNN",
#       "model": "gpt-3.5-turbo-0613",
#       "created_at": 1695838682,
#       "finished_at": 1695839006,
#       "fine_tuned_model": "ft:gpt-3.5-turbo-0613:forbeslab::83TTzs4O",
#       "organization_id": "org-QzNdgHXihCg09dJeDFtqXcWA",
#       "result_files": [
#         "file-ptJHqqf4o0JBfBtBanBi6Bc5"
#       ],
#       "status": "succeeded",
#       "validation_file": null,
#       "training_file": "file-sQoUKIivVgjlR85xUFO9pv6V",
#       "hyperparameters": {
#         "n_epochs": 4
#       },
#       "trained_tokens": 357752,
#       "error": null
#     },
#     {
#       "object": "fine_tuning.job",
#       "id": "ftjob-mOFMHY99rkBaEEZuFaIMSjTT",
#       "model": "gpt-3.5-turbo-0613",
#       "created_at": 1695496775,
#       "finished_at": 1695497085,
# ...
