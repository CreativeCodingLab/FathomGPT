# %%
# !pip3 install openai

# %%
import os
import openai
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.File.create(
  file=open("with-observation.jsonl", "rb"),
  purpose='fine-tune'
)
# Out:
# <File file id=file-XIWpwdsgT0nbcYUMmKbBP9Rr at 0x108776cf0> JSON: {
#   "object": "file",
#   "id": "file-XIWpwdsgT0nbcYUMmKbBP9Rr",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 476664,
#   "created_at": 1696031084,
#   "status": "uploaded",
#   "status_details": null
# }

# %%
openai.FineTuningJob.create(training_file="file-sQoUKIivVgjlR85xUFO9pv6V", model="gpt-4-0613")
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 openai.FineTuningJob.create(training_file="file-sQoUKIivVgjlR85xUFO9pv6V", model="gpt-4-0613")
#
# File /opt/homebrew/lib/python3.11/site-packages/openai/api_resources/abstract/createable_api_resource.py:57, in CreateableAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#      38 @classmethod
#      39 def create(
#      40     cls,
#    (...)
#      47     **params,
#      48 ):
#      49     requestor, url = cls.__prepare_create_requestor(
#      50         api_key,
#      51         api_base,
#    (...)
#      54         organization,
#      55     )
# ---> 57     response, _, api_key = requestor.request(
#      58         "post", url, params, request_id=request_id
#      59     )
#      61     return util.convert_to_openai_object(
# ...

# %%
openai.FineTuningJob.list(limit=10)
# Out:
# <OpenAIObject list at 0x109494530> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "fine_tuning.job",
#       "id": "ftjob-TRB5DR77lQAbq7tmkEZqjfNN",
#       "model": "gpt-3.5-turbo-0613",
#       "created_at": 1695838682,
#       "finished_at": 1695839006,
#       "fine_tuned_model": "ft:gpt-3.5-turbo-0613:forbeslab::83TTzs4O",
#       "organization_id": "org-QzNdgHXihCg09dJeDFtqXcWA",
#       "result_files": [
#         "file-ptJHqqf4o0JBfBtBanBi6Bc5"
#       ],
#       "status": "succeeded",
#       "validation_file": null,
#       "training_file": "file-sQoUKIivVgjlR85xUFO9pv6V",
#       "hyperparameters": {
#         "n_epochs": 4
#       },
#       "trained_tokens": 357752,
#       "error": null
#     },
#     {
#       "object": "fine_tuning.job",
#       "id": "ftjob-mOFMHY99rkBaEEZuFaIMSjTT",
#       "model": "gpt-3.5-turbo-0613",
#       "created_at": 1695496775,
#       "finished_at": 1695497085,
# ...
