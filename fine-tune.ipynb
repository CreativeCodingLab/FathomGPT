# %%
# !pip3 install openai
# Out:
# ...
#   Obtaining dependency information for openai from https://files.pythonhosted.org/packages/ae/59/911d6e5f1d7514d79c527067643376cddcf4cb8d1728e599b3b03ab51c69/openai-0.28.0-py3-none-any.whl.metadata
#   Using cached openai-0.28.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Obtaining dependency information for tqdm from https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl.metadata
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Obtaining dependency information for aiohttp from https://files.pythonhosted.org/packages/47/10/33abd984a476e314afdb4711fbd0aac1b25927676fa591445537da3aee98/aiohttp-3.8.5-cp311-cp311-macosx_11_0_arm64.whl.metadata
# ...
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# ...

# %%
import os
import openai
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.File.create(
  file=open("without-observation.jsonl", "rb"),
  purpose='fine-tune'
)
# Out:
# <File file id=file-vWh5CdGLT8tPoO4ypasBV4zE at 0x10bed9d90> JSON: {
#   "object": "file",
#   "id": "file-vWh5CdGLT8tPoO4ypasBV4zE",
#   "purpose": "fine-tune",
#   "filename": "file",
#   "bytes": 463759,
#   "created_at": 1695496736,
#   "status": "uploaded",
#   "status_details": null
# }

# %%
openai.FineTuningJob.create(training_file="file-vWh5CdGLT8tPoO4ypasBV4zE", model="gpt-3.5-turbo")
# Out:
# <FineTuningJob fine_tuning.job id=ftjob-mOFMHY99rkBaEEZuFaIMSjTT at 0x10a977e90> JSON: {
#   "object": "fine_tuning.job",
#   "id": "ftjob-mOFMHY99rkBaEEZuFaIMSjTT",
#   "model": "gpt-3.5-turbo-0613",
#   "created_at": 1695496775,
#   "finished_at": null,
#   "fine_tuned_model": null,
#   "organization_id": "org-QzNdgHXihCg09dJeDFtqXcWA",
#   "result_files": [],
#   "status": "validating_files",
#   "validation_file": null,
#   "training_file": "file-vWh5CdGLT8tPoO4ypasBV4zE",
#   "hyperparameters": {
#     "n_epochs": "auto"
#   },
#   "trained_tokens": null,
#   "error": null
# }

# %%
openai.FineTuningJob.list(limit=10)
# Out:
# <OpenAIObject list at 0x106346e10> JSON: {
#   "object": "list",
#   "data": [
#     {
#       "object": "fine_tuning.job",
#       "id": "ftjob-mOFMHY99rkBaEEZuFaIMSjTT",
#       "model": "gpt-3.5-turbo-0613",
#       "created_at": 1695496775,
#       "finished_at": 1695497085,
#       "fine_tuned_model": "ft:gpt-3.5-turbo-0613:forbeslab::822X8OkV",
#       "organization_id": "org-QzNdgHXihCg09dJeDFtqXcWA",
#       "result_files": [
#         "file-JXNfZnbWg1maBSpjnuCkBKU7"
#       ],
#       "status": "succeeded",
#       "validation_file": null,
#       "training_file": "file-vWh5CdGLT8tPoO4ypasBV4zE",
#       "hyperparameters": {
#         "n_epochs": 4
#       },
#       "trained_tokens": 347100,
#       "error": null
#     }
#   ],
#   "has_more": false
# }
